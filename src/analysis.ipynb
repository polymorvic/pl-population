# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from matplotlib.ticker import FuncFormatter
import warnings
from utils.plot import format_with_space
from utils.preprocessing import 

warnings.filterwarnings("ignore")
sns.set_theme(style="whitegrid")

# %%
data = pd.read_excel('../data/tablica_2.xls', skiprows=5).iloc[1:75, 0:2]
data.columns = ['rok', 'populacja']

# %%
population2024 = int(pd.read_excel('../data/powierzchnia_i_ludnosc_w_przekroju_terytorialnym_w_2024_roku_tablice.xlsx', sheet_name='Tabl. 1', skiprows=2).iloc[1, 4] / 1000)

data.loc[len(data)] = ['2024', population2024]

# %%
data
# Out:
#      rok  populacja
# 1   1950    25035.0
# 2   1951    25507.0
# 3   1952    25999.0
# 4   1953    26511.0
# 5   1954    27012.0
# ..   ...        ...
# 70  2019    38383.0
# 71  2020    38089.0
# 72  2021    37908.0
# 73  2022    37766.0
# 74  2024    37636.0
#
# [74 rows x 2 columns]

# %%
plt.figure(figsize=(10, 6))
sns.lineplot(data = data, x='rok', y='populacja')
plt.xlabel('Rok')
plt.ylabel('Populacja [tys.]')
plt.title('Populacja Polski w latach 1950-2024')
plt.gca().yaxis.set_major_formatter(FuncFormatter(format_with_space))
plt.tight_layout()
plt.show()
